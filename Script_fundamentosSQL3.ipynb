# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge2018/DataScience2022-2/blob/main/Script_fundamentosSQL3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
school_df = pd.read_csv(r'https://raw.githubusercontent.com/Jorge2018/RepositorioArchivos/main/School_Details.csv')
school_df.head(2)
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName ConstituencyName  ...  \
# 0    State Govt.             BUDANG         Gangtok          Rhenock  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok      West Pandam  ...
#
#   EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0           28126                       58.0                 8.0
# 1           15342                       50.0                 0.0
#
# ...

# %%
facility = pd.read_csv(r'https://raw.githubusercontent.com/Jorge2018/RepositorioArchivos/main/School_Facility_Details.csv')
facility.head(2)
# Out:
#   EstablishmentCode                                  EstablishmentName  \
# 0             S1034  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...
# 1             S0516                10TH MILE GOVERNMENT PRIMARY SCHOOL
#
#   IsLibraryAvailable  AvailableBooksCount IsFireExtgAvailable  \
# 0      Not Available                    0           Available
# 1      Not Available                    0       Not Available
#
#    ExtinguisherCount HOIRoomAvailable IsStaffRoomAvailable  NoofStaffRoom  \
# 0                  1        Available        Not Available              0
# 1                  0        Available            Available              1
#
#   IsLockerForStaffAvailable IsSportsStoreRoomAvailable
# 0             Not Available              Not Available
# 1             Not Available              Not Available

# %%
school_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DistrictName                1249 non-null   object
#  1   EstablishmentCode           1249 non-null   object
#  2   EstablishmentName           1249 non-null   object
#  3   BRCName                     1249 non-null   object
#  4   CRCName                     1249 non-null   object
#  5   SchoolLevel                 1246 non-null   object
#  6   ManagementName              1246 non-null   object
#  7   LocalityHabitation          1221 non-null   object
#  8   SubdivisionName             1241 non-null   object
#  9   ConstituencyName            1249 non-null   object
#  10  RevenueBlockName            1249 non-null   object
#  11  CivicBodyName               1249 non-null   object
#  12  WardName                    1249 non-null   object
# ...

# %%
facility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EstablishmentCode           1256 non-null   object
#  1   EstablishmentName           1256 non-null   object
#  2   IsLibraryAvailable          1256 non-null   object
#  3   AvailableBooksCount         1256 non-null   int64
#  4   IsFireExtgAvailable         1256 non-null   object
#  5   ExtinguisherCount           1256 non-null   int64
#  6   HOIRoomAvailable            1256 non-null   object
#  7   IsStaffRoomAvailable        1256 non-null   object
#  8   NoofStaffRoom               1256 non-null   int64
#  9   IsLockerForStaffAvailable   1256 non-null   object
#  10  IsSportsStoreRoomAvailable  1256 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 108.1+ KB

# %% [markdown]
# *Creacion de bbdd y conection*

# %%
# create sqlite engine for a database called schools
engine = create_engine('sqlite:///schools.db', echo=True)
# create connection to engine
conn = engine.connect()

# %% [markdown]
# *Agregacion de tb a la bbdd recien creada*

# %%
# add the dataframe as a table in sqlite
sqlite_table = "school"
school_df.to_sql(sqlite_table, conn, if_exists='fail')
sqlite_table2 = "school_facility"
facility.to_sql(sqlite_table2, conn, if_exists='fail')
# Out:
# 2022-10-04 15:45:39,568 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school")
# INFO:sqlalchemy.engine.Engine:PRAGMA main.table_info("school")
# 2022-10-04 15:45:39,572 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2022-10-04 15:45:39,580 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school")
# INFO:sqlalchemy.engine.Engine:PRAGMA temp.table_info("school")
# 2022-10-04 15:45:39,583 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2022-10-04 15:45:39,597 INFO sqlalchemy.engine.Engine
# CREATE TABLE school (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# ...

# %% [markdown]
# # R1

# %%
# Write your SQL query in this string
sql = """
SELECT AVG(`BACDistance (in Km)`) AS avg_bac_distance FROM SCHOOL ;
"""
# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-10-04 15:48:50,622 INFO sqlalchemy.engine.Engine
# SELECT AVG(`BACDistance (in Km)`) AS avg_bac_distance FROM SCHOOL
# INFO:sqlalchemy.engine.Engine:
# SELECT AVG(`BACDistance (in Km)`) AS avg_bac_distance FROM SCHOOL
# 2022-10-04 15:48:50,626 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#    avg_bac_distance
# 0         12.681822

# %% [markdown]
# # R2

# %%
# Write the SQL query
sql = """SELECT SchoolLevel,AVG(`BACDistance (in Km)`) AS avg_bac_distance 
FROM SCHOOL
GROUP BY SchoolLevel
ORDER BY  AVG(`BACDistance (in Km)`) DESC ;
 """
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-10-04 15:51:12,491 INFO sqlalchemy.engine.Engine SELECT SchoolLevel,AVG(`BACDistance (in Km)`) AS avg_bac_distance
# FROM SCHOOL
# GROUP BY SchoolLevel
# ORDER BY  AVG(`BACDistance (in Km)`) DESC ;
# INFO:sqlalchemy.engine.Engine:SELECT SchoolLevel,AVG(`BACDistance (in Km)`) AS avg_bac_distance
# FROM SCHOOL
# GROUP BY SchoolLevel
# ORDER BY  AVG(`BACDistance (in Km)`) DESC ;
# 2022-10-04 15:51:12,497 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0         JHS         13.692647
# 1          PS         12.830787
# 2          SS         12.630872
# 3         SSS         10.863095
# 4         LPS          5.368421
# 5        None               NaN

# %% [markdown]
# # R3

# %%
# Write the SQL query
sql = """SELECT SchoolLevel,AVG(`BACDistance (in Km)`) AS avg_bac_distance 
FROM SCHOOL
GROUP BY SchoolLevel
HAVING AVG(`BACDistance (in Km)`) > 10
 ;
 """
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-10-04 15:54:01,691 INFO sqlalchemy.engine.Engine SELECT SchoolLevel,AVG(`BACDistance (in Km)`) AS avg_bac_distance
# FROM SCHOOL
# GROUP BY SchoolLevel
# HAVING AVG(`BACDistance (in Km)`) > 10
#  ;
# INFO:sqlalchemy.engine.Engine:SELECT SchoolLevel,AVG(`BACDistance (in Km)`) AS avg_bac_distance
# FROM SCHOOL
# GROUP BY SchoolLevel
# HAVING AVG(`BACDistance (in Km)`) > 10
#  ;
# 2022-10-04 15:54:01,699 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0         JHS         13.692647
# 1          PS         12.830787
# 2          SS         12.630872
# 3         SSS         10.863095

# %% [markdown]
# # R4

# %%
# Write the SQL query
sql = """SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
UNO.EstablishmentCode=DOS.EstablishmentCode
LIMIT 2
 ;
 """
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-10-04 15:56:11,689 INFO sqlalchemy.engine.Engine SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
# UNO.EstablishmentCode=DOS.EstablishmentCode
# LIMIT 2
#  ;
# INFO:sqlalchemy.engine.Engine:SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
# UNO.EstablishmentCode=DOS.EstablishmentCode
# LIMIT 2
#  ;
# 2022-10-04 15:56:11,695 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
# ...

# %% [markdown]
# # R5

# %%
# Write the SQL query
sql = """SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
UNO.EstablishmentCode=DOS.EstablishmentCode
WHERE UNO.SCHOOLLEVEL='PS'
 ;
 """
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-10-04 15:58:23,284 INFO sqlalchemy.engine.Engine SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
# UNO.EstablishmentCode=DOS.EstablishmentCode
# WHERE UNO.SCHOOLLEVEL='PS'
#  ;
# INFO:sqlalchemy.engine.Engine:SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
# UNO.EstablishmentCode=DOS.EstablishmentCode
# WHERE UNO.SCHOOLLEVEL='PS'
#  ;
# 2022-10-04 15:58:23,292 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#      index DistrictName EstablishmentCode  \
# 0        0         East             S0169
# 1        5         East             S0856
# 2        6         East             S0870
# 3        7         East             S0157
# 4        8         East             S0876
# ..     ...          ...               ...
# 618   1244         West             S0336
# 619   1245         West             S0591
# 620   1246         West             S1045
# 621   1247         West             S0340
# ...

# %% [markdown]
# # R6

# %%
sql = """SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
UNO.EstablishmentCode=DOS.EstablishmentCode
WHERE UNO.SCHOOLLEVEL='PS'
ORDER BY UNO.EstablishmentName DESC
 ;
 """
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-10-04 15:59:06,062 INFO sqlalchemy.engine.Engine SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
# UNO.EstablishmentCode=DOS.EstablishmentCode
# WHERE UNO.SCHOOLLEVEL='PS'
# ORDER BY UNO.EstablishmentName DESC
#  ;
# INFO:sqlalchemy.engine.Engine:SELECT * FROM SCHOOL AS UNO INNER JOIN SCHOOL_FACILITY AS DOS ON
# UNO.EstablishmentCode=DOS.EstablishmentCode
# WHERE UNO.SCHOOLLEVEL='PS'
# ORDER BY UNO.EstablishmentName DESC
#  ;
# 2022-10-04 15:59:06,069 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#      index DistrictName EstablishmentCode  \
# 0      206         East             S0138
# 1      516        North             S0990
# 2     1031         West             S0288
# 3       66         East             S0207
# 4      141         East             S1157
# ..     ...          ...               ...
# 618    345         East             S0178
# 619   1102         West             S0374
# ...
