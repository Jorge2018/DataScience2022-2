# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge2018/DataScience2022-2/blob/main/Script_graficoInteres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
df= pd.read_csv(r'https://raw.githubusercontent.com/Jorge2018/DataScience2022-2/main/mortgages.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             1080 non-null   int64
#  1   Starting Balance  1080 non-null   float64
#  2   Repayment         1080 non-null   float64
#  3   Interest Paid     1080 non-null   float64
#  4   Principal Paid    1080 non-null   float64
#  5   New Balance       1080 non-null   float64
#  6   Mortgage Name     1080 non-null   object
#  7   Interest Rate     1080 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 67.6+ KB

# %%
filtro_porc=df['Interest Rate']==0.03
filtro_year=df['Mortgage Name']=='30 Year'
df_year30_porc03=df[filtro_porc & filtro_year]
df_year30_porc05=df[~filtro_porc & filtro_year]
#graficar la suma de esta columna Interest Paid
valdf03=df_year30_porc03['Interest Paid'].cumsum()
valdf05=df_year30_porc05['Interest Paid'].cumsum()

print('la cantidad de filas y col con 30 años del df son:(fila,col)',df[filtro_year].shape)
print('------------------------------------------')
print('los 3 primeros valores del suma acumulativa con un porc del 3% son:\n',valdf03.head(3))
# Out:
# la cantidad de filas y col con 30 años del df son:(fila,col) (720, 8)
# ------------------------------------------
# los 3 primeros valores del suma acumulativa con un porc del 3% son:
#  0    1000.00
# 1    1998.28
# 2    2994.84
# Name: Interest Paid, dtype: float64

# %%
x = df_year30_porc03['Month']
y = valdf03
y1= valdf05
x1= df_year30_porc05['Month']
plt.figure(dpi=100)
plt.plot(x,y,c='b')
plt.plot(x1,y1,c='k' )
plt.xticks(rotation=90)
plt.show()
